# %%
import math

# %%
math.sqrt(49)
# Out:
# 7.0

# %%
import jovian

# %%
from jovian.pythondsa import evaluate_test_cases

# %%
# we will define our function later

def locate_cards(cards, query):
    pass

# %%
# test cases for linear search algorithm

test = {
    'input':{
        'cards' : [10, 9, 8, 7, 4, 3, 2],
        'query' : 7
    },
    'output' : 3
}

# %%
tests = []

# %%
# query is in the middle of the list
tests.append(test)

tests.append({
    'input': {
        'cards' : [8, 7, 6, 5],
        'query' : 7
    },
    'output' : 1
})

# %%
#query is the first element

tests.append({
    'input' : {
        'cards' : [1, 0, -1, -2],
        'query' : 1
    },
    'output' : 0
})

# %%
#query is the last element

tests.append({
    'input' : {
        'cards' : [1, 0, -1, -2],
        'query' : -2
    },
    'output' : 3
})

# %%
#query is the not in the list

tests.append({
    'input' : {
        'cards' : [1, 0, -1, -2],
        'query' : 2
    },
    'output' : -1
})

# %%
#query occurs multiple times (return the first occurence)

tests.append({
    'input' : {
        'cards' : [1, 1, 0, -1, -2],
        'query' : 1
    },
    'output' : 0
})

# %%
# repeating elements in cards list

tests.append({
    'input' : {
        'cards' : [1, 1, 1, 0, -1, -2, -2, -2],
        'query' : 0
    },
    'output' : 3
})

# %%
# cards is empty

tests.append({
    'input' : {
        'cards' : [],
        'query' : 8
    },
    'output' : -1
})

# %% [markdown]
# We haven't set our locate cards function for Linear Search Algorithm yet.

# %%
result = evaluate_test_cases(locate_cards, tests)
# Out:
# TEST CASE #0
#
# Input:
# {'cards': [10, 9, 8, 7, 4, 3, 2], 'query': 7}
#
# Expected Output:
# 3
#
#
# Actual Output:
# None
#
# Execution Time:
# 0.003 ms
#
# Test Result:
# FAILED
#
#
# TEST CASE #1
#
# Input:
# {'cards': [8, 7, 6, 5], 'query': 7}
#
# Expected Output:
# 1
#
#
# Actual Output:
# None
#
# Execution Time:
# 0.002 ms
#
# Test Result:
# FAILED
#
#
# TEST CASE #2
#
# Input:
# {'cards': [1, 0, -1, -2], 'query': 1}
#
# Expected Output:
# 0
#
#
# Actual Output:
# None
#
# Execution Time:
# 0.002 ms
#
# Test Result:
# FAILED
#
#
# TEST CASE #3
#
# Input:
# {'cards': [1, 0, -1, -2], 'query': -2}
#
# Expected Output:
# 3
#
#
# Actual Output:
# None
#
# Execution Time:
# 0.001 ms
#
# Test Result:
# FAILED
#
#
# TEST CASE #4
#
# Input:
# {'cards': [1, 0, -1, -2], 'query': 2}
#
# Expected Output:
# -1
#
#
# Actual Output:
# None
#
# Execution Time:
# 0.002 ms
#
# Test Result:
# FAILED
#
#
# TEST CASE #5
#
# Input:
# {'cards': [1, 1, 0, -1, -2], 'query': 1}
#
# Expected Output:
# ...

# %%
def locate_card(cards, query):
    # create a position variable with value 0
    position = -1
    
    # iterating over cards list in a linear fashion
    for i in range(len(cards)):
        if cards[i] == query:
            position = i
            break
    
    return position

# %%
result = evaluate_test_cases(locate_card, tests)
# Out:
# TEST CASE #0
#
# Input:
# {'cards': [10, 9, 8, 7, 4, 3, 2], 'query': 7}
#
# Expected Output:
# 3
#
#
# Actual Output:
# 3
#
# Execution Time:
# 0.017 ms
#
# Test Result:
# PASSED
#
#
# TEST CASE #1
#
# Input:
# {'cards': [8, 7, 6, 5], 'query': 7}
#
# Expected Output:
# 1
#
#
# Actual Output:
# 1
#
# Execution Time:
# 0.009 ms
#
# Test Result:
# PASSED
#
#
# TEST CASE #2
#
# Input:
# {'cards': [1, 0, -1, -2], 'query': 1}
#
# Expected Output:
# 0
#
#
# Actual Output:
# 0
#
# Execution Time:
# 0.007 ms
#
# Test Result:
# PASSED
#
#
# TEST CASE #3
#
# Input:
# {'cards': [1, 0, -1, -2], 'query': -2}
#
# Expected Output:
# 3
#
#
# Actual Output:
# 3
#
# Execution Time:
# 0.013 ms
#
# Test Result:
# PASSED
#
#
# TEST CASE #4
#
# Input:
# {'cards': [1, 0, -1, -2], 'query': 2}
#
# Expected Output:
# -1
#
#
# Actual Output:
# -1
#
# Execution Time:
# 0.01 ms
#
# Test Result:
# PASSED
#
#
# TEST CASE #5
#
# Input:
# {'cards': [1, 1, 0, -1, -2], 'query': 1}
#
# Expected Output:
# 0
#
#
# ...

# %% [markdown]
# # DONE!
